# %%
import os
import pickle
import matplotlib.pyplot as plt

# %%
def load_file(path):
    with open(path, 'rb') as file:
        history = pickle.load(file)
    return history

# %%
history_os_8 = load_file('./saved/dlv3_os_8_history.pkl')
history_os_16 = load_file('./saved/dlv3_os_16_history.pkl')

# %%
def plot_metric_across_models(histories, labels, key="loss", save_path=None):
    assert len(histories) == len(labels), "Number of histories and labels must match"
    plt.figure(figsize=(6, 4))

    for i, his in enumerate(histories):
        values = [epoch[key] for epoch in his]
        plt.plot(range(1, len(values) + 1), values, marker='.', label=labels[i])

    plt.title(f"{key.capitalize()} over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel(key.capitalize())
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    if save_path:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path, dpi=300)

    plt.show()

# %%
plot_metric_across_models(
    [history_os_8['train'], history_os_8['val'], history_os_16['train'], history_os_16['val']],
    ["DLV3 R50 OS 8 Train", "DLV3 R50 OS 8 Val", "DLV3 R50 OS 16 Train", "DLV3 R50 OS 16 Val"],
    key="loss",
    save_path="./outputs/dlv3_loss.png",
)

# %%
plot_metric_across_models(
    [history_os_8['train'], history_os_8['val'], history_os_16['train'], history_os_16['val']],
    ["DLV3 R50 OS 8 Train", "DLV3 R50 OS 8 Val", "DLV3 R50 OS 16 Train", "DLV3 R50 OS 16 Val"],
    key="mean_iou",
    save_path="./outputs/dlv3_miou.png",
)

# %%
plot_metric_across_models(
    [history_os_8['train'], history_os_8['val'], history_os_16['train'], history_os_16['val']],
    ["DLV3 R50 OS 8 Train", "DLV3 R50 OS 8 Val", "DLV3 R50 OS 16 Train", "DLV3 R50 OS 16 Val"],
    key="mean_dice",
    save_path="./outputs/dlv3_mdice.png",
)

# %%
plot_metric_across_models(
    [history_os_8['train'], history_os_8['val'], history_os_16['train'], history_os_16['val']],
    ["DLV3 R50 OS 8 Train", "DLV3 R50 OS 8 Val", "DLV3 R50 OS 16 Train", "DLV3 R50 OS 16 Val"],
    key="mean_pixel_accuracy",
    save_path="./outputs/dlv3_mpacc.png",
)
